# %% [markdown]
# ## What is function?
# ### A, function is a named, reusable block of code.
# ## Types of functions:
# ### 1. In-built function - print(),id(),type(),len()..etc
# ### 2. User defined function - The function defined by the developer as per the requirements called user defined function.

# %%
## Syntex of function:

#### def function_name(peramenters...):
####     '''doc string'''
#### 
####     statement2
####     statement1
#### 
####     return (anything)

#### function_name()

# %% [markdown]
# ### parameter and arguments
# #### parameter - a parameter is a varible that receives a value when the function is called.
# #### Arguments - an argument is a actuall is passed to a function when it is called.

# %% [markdown]
# ### Types of arguments
# #### 1. positional arguments - function_name(a,b)
# #### 2. keyword arguments - function_name(a=10, b=20)
# #### 3. default arguments - function_name(a=0,b=0)
# #### 4. variable length arguments - function_name(*args)
# #### 5. keyword lenth arguments - function_name(**kwargs)

# %% [markdown]
# ### Python function ek se zyada value kaise return karta hai?
# #### Tuple packing/unpacking use kerke

# %% [markdown]
# ### variable scope
# #### variable scope means where the variable is accessible in the program.
# ### Types of variable scope.
# #### mainly two types ke hote hai. but in advance three type ke hote ha.
# #### 1. local variabel - a variable declare inside a function.
# #### 2. global variable - a variable declare outside of all function.
# #### 3. non-local variable - a non local is used in a nasted function using nonlocal keyword.
