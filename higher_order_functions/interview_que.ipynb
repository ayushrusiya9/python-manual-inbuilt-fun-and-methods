# %% [markdown]
# ## 1. Difference between return and print?
# #### Ans: return hold values and terminat a function, print() only display output on the terminal.
# ## 2. Can a function return multiple values?
# #### Ans: Yes, function return multiple value as a tuple.
# ## 3. What is a first-class function?
# #### Ans: A first class function is stored in a variable, pass in a function and return from another function.
# ## 4. What is *args vs **kwargs?
# #### Ans: *args is accepts multiple positional argumnts, **kwargs accepts multiple keyword arguments.
# ## 5. Local vs Global vs Nonlocal
# #### Ans: local - is defined inside a function, global is defined outside of any function, non-local is used in nasted function.
# ## 6. Why avoid global variables?
# #### Ans: because they make code hard to debug,maintain and reuse.
# ## 7. What happens if a function has no return?
# #### Ans: its return None by default.
# ## 8. What is a docstring and why is it used?
# #### Ans: A docstring is a string that explain what function does, and its used to documentation.
# ## 9. Function vs Method
# #### Ans: A function is independent called direct and the method is dependend on the class and objects called using class and object.
# ## 10. Can we pass a function as an argument?
# #### Ans: Yes.

# %% [markdown]
# # Higher order functions related que

# %% [markdown]
# ## 11. What is a higher-order function?
# #### Ans: a higher order function is that accepts and return another function.

# %%
# 12. Why does map() return an iterator?
# ans: code explaination.map() return itarator so it calculate value one by one only when needed. 
result = map(lambda x: x*2, [1,2,3])
print(result)
print(next(result))
print(next(result))

# %% [markdown]
# ## 13.
