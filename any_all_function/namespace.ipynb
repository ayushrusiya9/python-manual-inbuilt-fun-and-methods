# %% [markdown]
# ## Namespace
# ### A namespace is place where python store variable and functions name with their values.
# ### example:- x = 10

# %% [markdown]
# ## Types of namespace
# ### 1. local namespace
# ### 2. global namespace
# ### 3. builtin namespace

# %%
# local namespace
# names created insida a functions.
def test():
    a = 10
    print(locals())
test()
# Out:
# {'a': 10}

# %%
# global namespace
# names created outside of all functions.
a = 10
def test():
    x = 20
    print(x)
print(globals())
# Out:
# {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, '__loader__': None, '__spec__': None, '__builtin__': <module 'builtins' (built-in)>, '__builtins__': <module 'builtins' (built-in)>, '_ih': ['', '# local namespace\n# names created insida a functions.\ndef test():\n    a = 10\n    print(locals())\ntest()', '# global namespace\n# names created outside of all functions.\na = 10\ndef test():\n    return prin', '# global namespace\n# names created outside of all functions.\na = 10\ndef test():\n    x = 20\n    print(x)\nprint(globals())'], '_oh': {}, '_dh': [WindowsPath('c:/Users/ayush/Desktop/python-revision/any_all_function')], 'In': ['', '# local namespace\n# names created insida a functions.\ndef test():\n    a = 10\n    print(locals())\ntest()', '# global namespace\n# names created outside of all functions.\na = 10\ndef test():\n    return prin', '# global namespace\n# names created outside of all functions.\na = 10\ndef test():\n    x = 20\n    print(x)\nprint(globals())'], 'Out': {}, 'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x0000024449595940>>, 'exit': <IPython.core.autocall.ZMQExitAutocall object at 0x0000024449594410>, 'quit': <IPython.core.autocall.ZMQExitAutocall object at 0x0000024449594410>, 'open': <function open at 0x00000244475937E0>, '_': '', '__': '', '___': '', '__vsc_ipynb_file__': 'c:\\Users\\ayush\\Desktop\\python-revision\\any_all_function\\namespace.ipynb', '_i': '# global namespace\n# names created outside of all functions.\na = 10\ndef test():\n    return prin', '_ii': '# local namespace\n# names created insida a functions.\ndef test():\n    a = 10\n    print(locals())\ntest()', '_iii': '', '_i1': '# local namespace\n# names created insida a functions.\ndef test():\n    a = 10\n    print(locals())\ntest()', 'test': <function test at 0x0000024449A73560>, '_i2': '# global namespace\n# names created outside of all functions.\na = 10\ndef test():\n    return prin', 'a': 10, '_i3': '# global namespace\n# names created outside of all functions.\na = 10\ndef test():\n    x = 20\n    print(x)\nprint(globals())'}

# %%
# built in namespace
# names given by python itself.
import builtin
print(dir(builtin))
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'builtins']
